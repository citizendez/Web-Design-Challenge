# %%
import pandas as pd

# %%
df= pd.read_csv("cities.csv")
df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
df.to_html('data.html')

# %%
df_humid = df.loc[df['Humidity'] > 90]
df_humid
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 5          5      martyush          92      RU  1528905306        94  56.40
# 9          9     tuatapere           0      NZ  1528905312       100 -46.13
# 12        12  punta arenas           0      CL  1528902000       100 -53.16
# ..       ...           ...         ...     ...         ...       ...    ...
# 527      527     dhidhdhoo          88      MV  1528905605       100   6.88
# 533      533      pagudpud          90      PH  1528902000       100  18.56
# 538      538       calamar          92      CO  1528905629       100   1.96
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
df_lowhumid = df.loc[df['Humidity'] < 20]
df_lowhumid
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 25        25           gao          24      ML  1528905321        16  16.28
# 32        32          atar          20      MR  1528902000        19  20.52
# 41        41        najran          40      SA  1528902000        13  17.54
# 78        78         bilma           0      NE  1528905351        12  18.69
# 213      213          zhob           0      PK  1528905423        10  31.34
# 226      226  boulder city           1      US  1528902900        11  35.98
# 228      228         arlit           0      NE  1528905432        14  18.74
# 240      240      ondangwa           0     NaN  1528902000        13 -17.91
# 282      282          adre          20      TD  1528905465        16  13.47
# 295      295       baghdad           0      IQ  1528902000        14  33.30
# 317      317      araouane           0      ML  1528905479        15  18.90
# ...

# %%
df_clouds = df.loc[df['Cloudiness'] == 0]
df_clouds
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# 7          7   broken hill           0      AU  1528905311        88 -31.97
# 8          8     harnosand           0      SE  1528903200        44  62.63
# 9          9     tuatapere           0      NZ  1528905312       100 -46.13
# ..       ...           ...         ...     ...         ...       ...    ...
# 516      516         mbeya           0      TZ  1528905593        40  -8.91
# 524      524         acari           0      BR  1528905599        48  -6.44
# 526      526     troitskiy           0      RU  1528903800        48  45.15
# 531      531        sokoni           0      CD  1528905646        37 -12.89
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
df_maxclouds = df.loc[df['Cloudiness'] == 100]
df_maxclouds
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 53        53      lorengau         100      PG  1528905336       100  -2.02
# 151      151         vaini         100      IN  1528905392        98  15.34
# 258      258         along         100      IN  1528905450        98  28.17
# 300      300  christchurch         100      NZ  1528903800        93 -43.53
#
#         Lng  Max Temp  Wind Speed
# 1    169.85     42.61        5.64
# 53   147.27     80.59        3.85
# 151   74.49     70.42        4.29
# 258   94.80     68.89        1.50
# 300  172.64     48.20        8.05

# %%
df_humid.to_html('high_humid.html')
df_lowhumid.to_html('low_humid.html')
df_clouds.to_html('low_clouds.t')
